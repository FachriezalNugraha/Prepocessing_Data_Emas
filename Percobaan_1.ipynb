# %%
import pandas as pd

# %%
Hargaemas = pd.read_csv('dataminer.csv')

# %%
Hargaemas
# Out:
#          Tanggal Nama Logam       Harga
# 0     30/12/2019    BUYBACK  Rp 678.000
# 1     30/12/2019       GOLD  Rp 762.000
# 2     27/12/2019    BUYBACK  Rp 678.000
# 3     27/12/2019       GOLD  Rp 762.000
# 4     26/12/2019    BUYBACK  Rp 673.000
# ...          ...        ...         ...
# 1518  05/01/2017       GOLD  Rp 547.000
# 1519  04/01/2017    BUYBACK  Rp 500.000
# 1520  04/01/2017       GOLD  Rp 546.000
# 1521  03/01/2017    BUYBACK  Rp 496.000
# 1522  03/01/2017       GOLD  Rp 546.000
#
# [1523 rows x 3 columns]

# %%
Hargabeli = Hargaemas[Hargaemas["Nama Logam"] == "GOLD"]
Hargabeli
# Out:
#          Tanggal Nama Logam       Harga
# 1     30/12/2019       GOLD  Rp 762.000
# 3     27/12/2019       GOLD  Rp 762.000
# 5     26/12/2019       GOLD  Rp 758.000
# 7     23/12/2019       GOLD  Rp 752.000
# 9     21/12/2019       GOLD  Rp 752.000
# ...          ...        ...         ...
# 1514  09/01/2017       GOLD  Rp 542.000
# 1516  06/01/2017       GOLD  Rp 546.000
# 1518  05/01/2017       GOLD  Rp 547.000
# 1520  04/01/2017       GOLD  Rp 546.000
# 1522  03/01/2017       GOLD  Rp 546.000
#
# [760 rows x 3 columns]

# %%
Hargajual = Hargaemas[Hargaemas["Nama Logam"] == "BUYBACK"]
Hargajual
# Out:
#          Tanggal Nama Logam       Harga
# 0     30/12/2019    BUYBACK  Rp 678.000
# 2     27/12/2019    BUYBACK  Rp 678.000
# 4     26/12/2019    BUYBACK  Rp 673.000
# 6     23/12/2019    BUYBACK  Rp 665.000
# 8     21/12/2019    BUYBACK  Rp 665.000
# ...          ...        ...         ...
# 1513  09/01/2017    BUYBACK  Rp 502.000
# 1515  06/01/2017    BUYBACK  Rp 506.000
# 1517  05/01/2017    BUYBACK  Rp 503.000
# 1519  04/01/2017    BUYBACK  Rp 500.000
# 1521  03/01/2017    BUYBACK  Rp 496.000
#
# [763 rows x 3 columns]

# %%
data = {
    'Tanggal' : Hargajual.Tanggal,
    'Harga_beli' : Hargabeli.Harga,
    'Harga_jual' : Hargajual.Harga
}
data
# Out:
# {'Tanggal': 0       30/12/2019
#  2       27/12/2019
#  4       26/12/2019
#  6       23/12/2019
#  8       21/12/2019
#             ...
#  1513    09/01/2017
#  1515    06/01/2017
#  1517    05/01/2017
#  1519    04/01/2017
#  1521    03/01/2017
#  Name: Tanggal, Length: 763, dtype: object,
#  'Harga_beli': 1       Rp 762.000
#  3       Rp 762.000
#  5       Rp 758.000
#  7       Rp 752.000
#  9       Rp 752.000
#             ...
#  1514    Rp 542.000
#  1516    Rp 546.000
#  1518    Rp 547.000
#  1520    Rp 546.000
#  1522    Rp 546.000
#  Name: Harga, Length: 760, dtype: object,
#  'Harga_jual': 0       Rp 678.000
#  2       Rp 678.000
#  4       Rp 673.000
#  6       Rp 665.000
#  8       Rp 665.000
#             ...
#  1513    Rp 502.000
#  1515    Rp 506.000
#  1517    Rp 503.000
#  1519    Rp 500.000
#  1521    Rp 496.000
#  Name: Harga, Length: 763, dtype: object}

# %%
Hargabeli = Hargabeli.reset_index()

# %%
Hargabeli
# Out:
#      index     Tanggal Nama Logam       Harga
# 0        1  30/12/2019       GOLD  Rp 762.000
# 1        3  27/12/2019       GOLD  Rp 762.000
# 2        5  26/12/2019       GOLD  Rp 758.000
# 3        7  23/12/2019       GOLD  Rp 752.000
# 4        9  21/12/2019       GOLD  Rp 752.000
# ..     ...         ...        ...         ...
# 755   1514  09/01/2017       GOLD  Rp 542.000
# 756   1516  06/01/2017       GOLD  Rp 546.000
# 757   1518  05/01/2017       GOLD  Rp 547.000
# 758   1520  04/01/2017       GOLD  Rp 546.000
# 759   1522  03/01/2017       GOLD  Rp 546.000
#
# [760 rows x 4 columns]

# %%
Hargajual = Hargajual.reset_index()

# %%
Hargajual
# Out:
#      index     Tanggal Nama Logam       Harga
# 0        0  30/12/2019    BUYBACK  Rp 678.000
# 1        2  27/12/2019    BUYBACK  Rp 678.000
# 2        4  26/12/2019    BUYBACK  Rp 673.000
# 3        6  23/12/2019    BUYBACK  Rp 665.000
# 4        8  21/12/2019    BUYBACK  Rp 665.000
# ..     ...         ...        ...         ...
# 758   1513  09/01/2017    BUYBACK  Rp 502.000
# 759   1515  06/01/2017    BUYBACK  Rp 506.000
# 760   1517  05/01/2017    BUYBACK  Rp 503.000
# 761   1519  04/01/2017    BUYBACK  Rp 500.000
# 762   1521  03/01/2017    BUYBACK  Rp 496.000
#
# [763 rows x 4 columns]

# %%
datasaya = pd.DataFrame(data)

# %%
datasaya
# Out:
#          Tanggal  Harga_beli  Harga_jual
# 0     30/12/2019         NaN  Rp 678.000
# 1            NaN  Rp 762.000         NaN
# 2     27/12/2019         NaN  Rp 678.000
# 3            NaN  Rp 762.000         NaN
# 4     26/12/2019         NaN  Rp 673.000
# ...          ...         ...         ...
# 1518         NaN  Rp 547.000         NaN
# 1519  04/01/2017         NaN  Rp 500.000
# 1520         NaN  Rp 546.000         NaN
# 1521  03/01/2017         NaN  Rp 496.000
# 1522         NaN  Rp 546.000         NaN
#
# [1523 rows x 3 columns]

# %%
dataku = {
    'Tanggal' : Hargajual.Tanggal,
    'Harga_beli' : Hargabeli.Harga,
    'Harga_jual' : Hargajual.Harga
}
dataku
# Out:
# {'Tanggal': 0      30/12/2019
#  1      27/12/2019
#  2      26/12/2019
#  3      23/12/2019
#  4      21/12/2019
#            ...
#  758    09/01/2017
#  759    06/01/2017
#  760    05/01/2017
#  761    04/01/2017
#  762    03/01/2017
#  Name: Tanggal, Length: 763, dtype: object,
#  'Harga_beli': 0      Rp 762.000
#  1      Rp 762.000
#  2      Rp 758.000
#  3      Rp 752.000
#  4      Rp 752.000
#            ...
#  755    Rp 542.000
#  756    Rp 546.000
#  757    Rp 547.000
#  758    Rp 546.000
#  759    Rp 546.000
#  Name: Harga, Length: 760, dtype: object,
#  'Harga_jual': 0      Rp 678.000
#  1      Rp 678.000
#  2      Rp 673.000
#  3      Rp 665.000
#  4      Rp 665.000
#            ...
#  758    Rp 502.000
#  759    Rp 506.000
#  760    Rp 503.000
#  761    Rp 500.000
#  762    Rp 496.000
#  Name: Harga, Length: 763, dtype: object}

# %%
datakuh = pd.DataFrame(dataku)

# %%
datakuh
# Out:
#         Tanggal  Harga_beli  Harga_jual
# 0    30/12/2019  Rp 762.000  Rp 678.000
# 1    27/12/2019  Rp 762.000  Rp 678.000
# 2    26/12/2019  Rp 758.000  Rp 673.000
# 3    23/12/2019  Rp 752.000  Rp 665.000
# 4    21/12/2019  Rp 752.000  Rp 665.000
# ..          ...         ...         ...
# 758  09/01/2017  Rp 546.000  Rp 502.000
# 759  06/01/2017  Rp 546.000  Rp 506.000
# 760  05/01/2017         NaN  Rp 503.000
# 761  04/01/2017         NaN  Rp 500.000
# 762  03/01/2017         NaN  Rp 496.000
#
# [763 rows x 3 columns]

# %%
datakuh = datakuh.dropna()

# %%
datakuh
# Out:
#         Tanggal  Harga_beli  Harga_jual
# 0    30/12/2019  Rp 762.000  Rp 678.000
# 1    27/12/2019  Rp 762.000  Rp 678.000
# 2    26/12/2019  Rp 758.000  Rp 673.000
# 3    23/12/2019  Rp 752.000  Rp 665.000
# 4    21/12/2019  Rp 752.000  Rp 665.000
# ..          ...         ...         ...
# 755  12/01/2017  Rp 542.000  Rp 509.000
# 756  11/01/2017  Rp 546.000  Rp 507.000
# 757  10/01/2017  Rp 547.000  Rp 507.000
# 758  09/01/2017  Rp 546.000  Rp 502.000
# 759  06/01/2017  Rp 546.000  Rp 506.000
#
# [760 rows x 3 columns]

# %%
datakuh['Tanggal'] = pd.to_datetime(datakuh['Tanggal'])
# Out:
# <ipython-input-20-906d203e8d84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datakuh['Tanggal'] = pd.to_datetime(datakuh['Tanggal'])

# %%
datakuh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 759
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     760 non-null    datetime64[ns]
#  1   Harga_beli  760 non-null    object
#  2   Harga_jual  760 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 23.8+ KB

# %%
datakuh
# Out:
#        Tanggal  Harga_beli  Harga_jual
# 0   2019-12-30  Rp 762.000  Rp 678.000
# 1   2019-12-27  Rp 762.000  Rp 678.000
# 2   2019-12-26  Rp 758.000  Rp 673.000
# 3   2019-12-23  Rp 752.000  Rp 665.000
# 4   2019-12-21  Rp 752.000  Rp 665.000
# ..         ...         ...         ...
# 755 2017-12-01  Rp 542.000  Rp 509.000
# 756 2017-11-01  Rp 546.000  Rp 507.000
# 757 2017-10-01  Rp 547.000  Rp 507.000
# 758 2017-09-01  Rp 546.000  Rp 502.000
# 759 2017-06-01  Rp 546.000  Rp 506.000
#
# [760 rows x 3 columns]

# %%
for data in range(len(datakuh)):
    hasil_clean = datakuh['Harga_jual']
    print(hasil_clean)
# Out:
# 0      Rp 678.000
# 1      Rp 678.000
# 2      Rp 673.000
# 3      Rp 665.000
# 4      Rp 665.000
#           ...
# 755    Rp 509.000
# 756    Rp 507.000
# 757    Rp 507.000
# 758    Rp 502.000
# 759    Rp 506.000
# Name: Harga_jual, Length: 760, dtype: object
# 0      Rp 678.000
# 1      Rp 678.000
# 2      Rp 673.000
# 3      Rp 665.000
# 4      Rp 665.000
#           ...
# 755    Rp 509.000
# 756    Rp 507.000
# 757    Rp 507.000
# 758    Rp 502.000
# 759    Rp 506.000
# Name: Harga_jual, Length: 760, dtype: object
# 0      Rp 678.000
# 1      Rp 678.000
# 2      Rp 673.000
# 3      Rp 665.000
# 4      Rp 665.000
#           ...
# 755    Rp 509.000
# 756    Rp 507.000
# 757    Rp 507.000
# 758    Rp 502.000
# 759    Rp 506.000
# Name: Harga_jual, Length: 760, dtype: object
# 0      Rp 678.000
# 1      Rp 678.000
# 2      Rp 673.000
# 3      Rp 665.000
# 4      Rp 665.000
#           ...
# 755    Rp 509.000
# 756    Rp 507.000
# 757    Rp 507.000
# 758    Rp 502.000
# ...

# %%
for data in range(len(datakuh)):
    hasil_clean = datakuh['Harga_beli']
    print(hasil_clean)
# Out:
# 0      Rp 762.000
# 1      Rp 762.000
# 2      Rp 758.000
# 3      Rp 752.000
# 4      Rp 752.000
#           ...
# 755    Rp 542.000
# 756    Rp 546.000
# 757    Rp 547.000
# 758    Rp 546.000
# 759    Rp 546.000
# Name: Harga_beli, Length: 760, dtype: object
# 0      Rp 762.000
# 1      Rp 762.000
# 2      Rp 758.000
# 3      Rp 752.000
# 4      Rp 752.000
#           ...
# 755    Rp 542.000
# 756    Rp 546.000
# 757    Rp 547.000
# 758    Rp 546.000
# 759    Rp 546.000
# Name: Harga_beli, Length: 760, dtype: object
# 0      Rp 762.000
# 1      Rp 762.000
# 2      Rp 758.000
# 3      Rp 752.000
# 4      Rp 752.000
#           ...
# 755    Rp 542.000
# 756    Rp 546.000
# 757    Rp 547.000
# 758    Rp 546.000
# 759    Rp 546.000
# Name: Harga_beli, Length: 760, dtype: object
# 0      Rp 762.000
# 1      Rp 762.000
# 2      Rp 758.000
# 3      Rp 752.000
# 4      Rp 752.000
#           ...
# 755    Rp 542.000
# 756    Rp 546.000
# 757    Rp 547.000
# 758    Rp 546.000
# ...

# %%
datakuh
# Out:
#        Tanggal  Harga_beli  Harga_jual
# 0   2019-12-30  Rp 762.000  Rp 678.000
# 1   2019-12-27  Rp 762.000  Rp 678.000
# 2   2019-12-26  Rp 758.000  Rp 673.000
# 3   2019-12-23  Rp 752.000  Rp 665.000
# 4   2019-12-21  Rp 752.000  Rp 665.000
# ..         ...         ...         ...
# 755 2017-12-01  Rp 542.000  Rp 509.000
# 756 2017-11-01  Rp 546.000  Rp 507.000
# 757 2017-10-01  Rp 547.000  Rp 507.000
# 758 2017-09-01  Rp 546.000  Rp 502.000
# 759 2017-06-01  Rp 546.000  Rp 506.000
#
# [760 rows x 3 columns]

# %%
import re
data = "Rp 250.000"

data = re.sub("[^0-9]","",data)
print(data)
# Out:
# 250000

# %%
datafix = datakuh

data = re.sub("[^0-9]","",data)
print(datafix)
# Out:
#        Tanggal  Harga_beli  Harga_jual
# 0   2019-12-30  Rp 762.000  Rp 678.000
# 1   2019-12-27  Rp 762.000  Rp 678.000
# 2   2019-12-26  Rp 758.000  Rp 673.000
# 3   2019-12-23  Rp 752.000  Rp 665.000
# 4   2019-12-21  Rp 752.000  Rp 665.000
# ..         ...         ...         ...
# 755 2017-12-01  Rp 542.000  Rp 509.000
# 756 2017-11-01  Rp 546.000  Rp 507.000
# 757 2017-10-01  Rp 547.000  Rp 507.000
# 758 2017-09-01  Rp 546.000  Rp 502.000
# 759 2017-06-01  Rp 546.000  Rp 506.000
#
# [760 rows x 3 columns]

# %%
datafix =datakuh['Harga_jual']

data = re.sub("[^0-9]","",datafix)
print(datafix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-7f6937d664c7> in <module>
#       1 datafix =datakuh['Harga_jual']
#       2
# ----> 3 data = re.sub("[^0-9]","",datafix)
#       4 print(datafix)
#
# ~\anaconda3\envs\py38\lib\re.py in sub(pattern, repl, string, count, flags)
#     206     a callable, it's passed the Match object and must return
#     207     a replacement string to be used."""
# --> 208     return _compile(pattern, flags).sub(repl, string, count)
#     209
#     210 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
datakuh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 759
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     760 non-null    datetime64[ns]
#  1   Harga_beli  760 non-null    object
#  2   Harga_jual  760 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 23.8+ KB

# %%
datakuh["Harga_jual"].values
# Out:
# array(['Rp 678.000', 'Rp 678.000', 'Rp 673.000', 'Rp 665.000',
#        'Rp 665.000', 'Rp 664.000', 'Rp 664.000', 'Rp 664.500',
#        'Rp 664.000', 'Rp 662.500', 'Rp 663.000', 'Rp 661.000',
#        'Rp 664.500', 'Rp 658.500', 'Rp 658.000', 'Rp 659.000',
#        'Rp 662.500', 'Rp 668.000', 'Rp 669.500', 'Rp 670.500',
#        'Rp 663.000', 'Rp 661.500', 'Rp 663.500', 'Rp 659.500',
#        'Rp 659.500', 'Rp 661.000', 'Rp 658.000', 'Rp 661.500',
#        'Rp 662.000', 'Rp 664.000', 'Rp 667.000', 'Rp 667.000',
#        'Rp 665.000', 'Rp 664.000', 'Rp 664.000', 'Rp 665.500',
#        'Rp 662.000', 'Rp 658.500', 'Rp 656.500', 'Rp 658.000',
#        'Rp 658.000', 'Rp 661.000', 'Rp 669.500', 'Rp 669.500',
#        'Rp 678.000', 'Rp 683.000', 'Rp 684.000', 'Rp 684.000',
#        'Rp 674.000', 'Rp 670.900', 'Rp 671.000', 'Rp 679.000',
#        'Rp 679.000', 'Rp 675.000', 'Rp 673.000', 'Rp 672.000',
#        'Rp 673.000', 'Rp 677.000', 'Rp 678.000', 'Rp 680.000',
# ...

# %%
datakuh.to_csv('Datakuh.xlsx', index=False)

# %%
datakuh.to_csv('Datakuh.csv', index=False)

# %%
datakuh
# Out:
#        Tanggal  Harga_beli  Harga_jual
# 0   2019-12-30  Rp 762.000  Rp 678.000
# 1   2019-12-27  Rp 762.000  Rp 678.000
# 2   2019-12-26  Rp 758.000  Rp 673.000
# 3   2019-12-23  Rp 752.000  Rp 665.000
# 4   2019-12-21  Rp 752.000  Rp 665.000
# ..         ...         ...         ...
# 755 2017-12-01  Rp 542.000  Rp 509.000
# 756 2017-11-01  Rp 546.000  Rp 507.000
# 757 2017-10-01  Rp 547.000  Rp 507.000
# 758 2017-09-01  Rp 546.000  Rp 502.000
# 759 2017-06-01  Rp 546.000  Rp 506.000
#
# [760 rows x 3 columns]

# %%
datakuh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 759
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     760 non-null    datetime64[ns]
#  1   Harga_beli  760 non-null    object
#  2   Harga_jual  760 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 23.8+ KB

# %%
datakuh['Harga_jual'] = datakuh['Harga_jual'].str.replace('Rp', '')
# Out:
# <ipython-input-90-aefa7a42fd0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datakuh['Harga_jual'] = datakuh['Harga_jual'].str.replace('Rp', '')

# %%
datakuh
# Out:
#        Tanggal  Harga_beli Harga_jual
# 0   2019-12-30  Rp 762.000    678.000
# 1   2019-12-27  Rp 762.000    678.000
# 2   2019-12-26  Rp 758.000    673.000
# 3   2019-12-23  Rp 752.000    665.000
# 4   2019-12-21  Rp 752.000    665.000
# ..         ...         ...        ...
# 755 2017-12-01  Rp 542.000    509.000
# 756 2017-11-01  Rp 546.000    507.000
# 757 2017-10-01  Rp 547.000    507.000
# 758 2017-09-01  Rp 546.000    502.000
# 759 2017-06-01  Rp 546.000    506.000
#
# [760 rows x 3 columns]

# %%
datakuh['Harga_beli'] = datakuh['Harga_beli'].str.replace('Rp', '')
# Out:
# <ipython-input-92-b6f2d7432a63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datakuh['Harga_beli'] = datakuh['Harga_beli'].str.replace('Rp', '')

# %%
datakuh
# Out:
#        Tanggal Harga_beli Harga_jual
# 0   2019-12-30    762.000    678.000
# 1   2019-12-27    762.000    678.000
# 2   2019-12-26    758.000    673.000
# 3   2019-12-23    752.000    665.000
# 4   2019-12-21    752.000    665.000
# ..         ...        ...        ...
# 755 2017-12-01    542.000    509.000
# 756 2017-11-01    546.000    507.000
# 757 2017-10-01    547.000    507.000
# 758 2017-09-01    546.000    502.000
# 759 2017-06-01    546.000    506.000
#
# [760 rows x 3 columns]

# %%
datakuh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 759
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     760 non-null    datetime64[ns]
#  1   Harga_beli  760 non-null    object
#  2   Harga_jual  760 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 23.8+ KB

# %%
datakuh.to_excel('Datakuh1.xlsx', index=False)

# %%
datakuh.to_csv('Datakuh1.csv', index=False)
